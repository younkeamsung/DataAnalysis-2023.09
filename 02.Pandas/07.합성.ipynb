# %% [markdown]
# ### 2.7 데이터프레임 합성(merge)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - merge

# %%
df1 = pd.DataFrame({
    '고객번호': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    '이름': ['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호', '이름'])
df1
# Out:
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호': [1001, 1001, 1005, 1006, 1008, 1001],
    '금액': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['고객번호', '금액'])
df2
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
# Inner join - 컬럼명이 같은 열(고객번호)을 기준으로, 공통 데이터만 합성
pd.merge(df1, df2)
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
# Left outer join
pd.merge(df1, df2, how='left')
# Out:
#    고객번호   이름       금액
# 0  1001   둘리  10000.0
# 1  1001   둘리  20000.0
# 2  1001   둘리  30000.0
# 3  1002  도우너      NaN
# 4  1003   또치      NaN
# 5  1004   길동      NaN
# 6  1005   희동  15000.0
# 7  1006  마이콜   5000.0
# 8  1007   영희      NaN

# %%
# Right outer join
pd.merge(df1, df2, how='right')
# Out:
#    고객번호   이름      금액
# 0  1001   둘리   10000
# 1  1001   둘리   20000
# 2  1005   희동   15000
# 3  1006  마이콜    5000
# 4  1008  NaN  100000
# 5  1001   둘리   30000

# %%
# Full outer join
pd.merge(df1, df2, how='outer')
# Out:
#    고객번호   이름        금액
# 0  1001   둘리   10000.0
# 1  1001   둘리   20000.0
# 2  1001   둘리   30000.0
# 3  1002  도우너       NaN
# 4  1003   또치       NaN
# 5  1004   길동       NaN
# 6  1005   희동   15000.0
# 7  1006  마이콜    5000.0
# 8  1007   영희       NaN
# 9  1008  NaN  100000.0

# %% [markdown]
# - join() method

# %%
# index로 join
df1.set_index('고객번호', inplace=True)
df2.set_index('고객번호', inplace=True)

# %%
df1.join(df2)       # Left outer join
# Out:
#        이름       금액
# 고객번호
# 1001   둘리  10000.0
# 1001   둘리  20000.0
# 1001   둘리  30000.0
# 1002  도우너      NaN
# 1003   또치      NaN
# 1004   길동      NaN
# 1005   희동  15000.0
# 1006  마이콜   5000.0
# 1007   영희      NaN

# %%
# Inner join
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#        이름     금액
# 고객번호
# 1001   둘리  10000
# 1001   둘리  20000
# 1001   둘리  30000
# 1005   희동  15000
# 1006  마이콜   5000

# %% [markdown]
# - 연습문제 4.6.1

# %%
df3 = pd.DataFrame(np.random.randint(100, 110, size=(5,5)),columns=list('ABCDE'))
df3
# Out:
#      A    B    C    D    E
# 0  105  105  106  102  109
# 1  103  101  100  105  101
# 2  101  101  102  102  106
# 3  108  104  102  100  106
# 4  102  101  102  103  108

# %%
df4 = pd.DataFrame(np.random.randint(100, 110, size=(5,5)),columns=list('ABXYZ'))
df4
# Out:
#      A    B    X    Y    Z
# 0  106  109  106  105  107
# 1  106  101  108  108  108
# 2  109  106  100  103  108
# 3  106  104  102  103  104
# 4  105  105  105  101  101

# %%
# A 열 기준
pd.merge(df3, df4, on='A')
# Out:
#      A  B_x    C    D    E  B_y    X    Y    Z
# 0  105  105  106  102  109  105  105  101  101

# %%
# B 열 기준
pd.merge(df3, df4, on='B')
# Out:
#    A_x    B    C    D    E  A_y    X    Y    Z
# 0  105  105  106  102  109  105  105  101  101
# 1  103  101  100  105  101  106  108  108  108
# 2  101  101  102  102  106  106  108  108  108
# 3  102  101  102  103  108  106  108  108  108
# 4  108  104  102  100  106  106  102  103  104

# %%
# A열과 B열 기준
pd.merge(df3, df4, on=['A','B'])
# Out:
#      A    B    C    D    E    X    Y    Z
# 0  105  105  106  102  109  105  101  101

# %%
# C열 == X열 기준
pd.merge(df3, df4, left_on='C',right_on='X')
# Out:
#    A_x  B_x    C    D    E  A_y  B_y    X    Y    Z
# 0  105  105  106  102  109  106  109  106  105  107
# 1  103  101  100  105  101  109  106  100  103  108
# 2  101  101  102  102  106  106  104  102  103  104
# 3  108  104  102  100  106  106  104  102  103  104
# 4  102  101  102  103  108  106  104  102  103  104

# %% [markdown]
# - concat

# %%
df5 = pd.DataFrame(
    np.arange(6).reshape(3, 2),
    index=['a', 'b', 'c'],
    columns=['데이터1', '데이터2'])
df5
# Out:
#    데이터1  데이터2
# a     0     1
# b     2     3
# c     4     5

# %%
df6 = pd.DataFrame(
    5 + np.arange(4).reshape(2, 2),
    index=['a', 'c'],
    columns=['데이터3', '데이터4'])
df6
# Out:
#    데이터3  데이터4
# a     5     6
# c     7     8

# %%
pd.concat([df5, df5])           # Vertical stack
# Out:
#    데이터1  데이터2
# a     0     1
# b     2     3
# c     4     5
# a     0     1
# b     2     3
# c     4     5

# %%
pd.concat([df5, df6], axis=1)   # Horizontal stack
# Out:
#    데이터1  데이터2  데이터3  데이터4
# a     0     1   5.0   6.0
# b     2     3   NaN   NaN
# c     4     5   7.0   8.0

# %% [markdown]
# - 연습문제 4.6.2

# %%
df7 = pd.DataFrame(np.random.randint(500, 1000, size=(6,2)) * 1000,
                   columns=['매출','비용'], index='1월 2월 3월 4월 5월 6월'.split())
df7['이익'] = df7['매출'] - df7['비용']
df7
# Out:
#         매출      비용      이익
# 1월  879000  525000  354000
# 2월  935000  561000  374000
# 3월  849000  875000  -26000
# 4월  636000  720000  -84000
# 5월  725000  825000 -100000
# 6월  616000  607000    9000

# %%
df8 = pd.DataFrame(np.random.randint(500, 1000, size=(6,2)) * 1000,
                   columns=['매출','비용'], index='7월 8월 9월 10월 11월 12월'.split())
df8['이익'] = df8['매출'] - df8['비용']
df8
# Out:
#          매출      비용      이익
# 7월   741000  570000  171000
# 8월   633000  720000  -87000
# 9월   883000  860000   23000
# 10월  911000  764000  147000
# 11월  542000  884000 -342000
# 12월  854000  813000   41000

# %%
df9 = pd.concat([df7, df8], axis=0)
df9
# Out:
#          매출      비용      이익
# 1월   879000  525000  354000
# 2월   935000  561000  374000
# 3월   849000  875000  -26000
# 4월   636000  720000  -84000
# 5월   725000  825000 -100000
# 6월   616000  607000    9000
# 7월   741000  570000  171000
# 8월   633000  720000  -87000
# 9월   883000  860000   23000
# 10월  911000  764000  147000
# 11월  542000  884000 -342000
# 12월  854000  813000   41000

# %%
df9.loc['합계'] = df9.sum()
df9.tail()
# Out:
#           매출       비용      이익
# 9월    883000   860000   23000
# 10월   911000   764000  147000
# 11월   542000   884000 -342000
# 12월   854000   813000   41000
# 합계   9204000  8724000  480000
